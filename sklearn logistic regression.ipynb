# %%
import numpy as np
import matplotlib.pyplot as plt
from utilitypackage import *

# %%
z = np.arange(-7, 7 , 0.1)
y = sigmoid(z)

# %%
plt.plot(z , y)
plt.axvline(0)
plt.ylim(-0.1 , 1.1)
# Out:
# (-0.1, 1.1)
